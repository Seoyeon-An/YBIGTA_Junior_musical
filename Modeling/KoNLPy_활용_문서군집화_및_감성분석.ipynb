# %% [markdown]
# # 설치

# %%
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash
# Out:
# --2023-05-12 14:33:44--  https://www.dropbox.com/s/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz [following]
# --2023-05-12 14:33:44--  https://www.dropbox.com/s/dl/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc022afb68d4ab5f0443f3e15a50.dl.dropboxusercontent.com/cd/0/get/B7727M4Z93pSpq0Bo9pdZ7C_cr_wRhPgQCAsa9wr3GIGm8FWN1W4CjeR03bJvCpOmXBoR0Hdn_A8Pxk-0f2KT0crPPhbXEDa_rnX2wyX6a6aAm7r3ZNdMU_4-w7LSYCY97bXqkolWK5Wu3qahJ9zjzHnVquoUHRieGX7lGJRYoA3CsuAVO5aTrK7P-LTS1M4owQ/file?dl=1# [following]
# ...

# %%
# %%bash
# apt-get update
# apt-get install g++ openjdk-8-jdk python-dev python3-dev
# pip3 install JPype1
# pip3 install konlpy
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Get:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease [18.1 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:7 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:8 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:9 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,681 kB]
# Get:11 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease [24.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,343 kB]
# ...

# %%
# %env JAVA_HOME "/usr/lib/jvm/java-8-openjdk-amd64"
# Out:
# env: JAVA_HOME="/usr/lib/jvm/java-8-openjdk-amd64"

# %%
# %%bash
# bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)
# pip3 install python-mecab-ko
# Out:
# mecab-ko is already installed
# mecab-ko-dic is already installed
# Install mecab-python
# /tmp /content
# /content
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /tmp/mecab-python-0.996
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 573.9/573.9 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 25.6 MB/s eta 0:00:00
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# ...

# %% [markdown]
# # 동작 확인 테스트

# %%
# KoNLPy의 Okt 와 Mecab 불러와서 사용해보기
import konlpy
from konlpy.tag import Kkma, Komoran, Hannanum, Okt
from konlpy.utils import pprint
from mecab import MeCab
Okt = Okt()
mecab = MeCab()
# 예시 문장
sentence = "OMG 공부하기 넘 싫네요. 그래도 스터디 해야됩니다 오마이갓! 지쟈스 하 아~"

# %%
Okt.morphs(sentence)
# Out:
# ['OMG',
#  '공부',
#  '하기',
#  '넘',
#  '싫네요',
#  '.',
#  '그래도',
#  '스터디',
#  '해야',
#  '됩니다',
#  '오마이갓',
#  '!',
#  '지쟈스',
#  '하',
#  '아',
#  '~']

# %%
mecab.morphs(sentence)
# Out:
# ['OMG',
#  '공부',
#  '하',
#  '기',
#  '넘',
#  '싫',
#  '네요',
#  '.',
#  '그래도',
#  '스터디',
#  '해야',
#  '됩니다',
#  '오마이갓',
#  '!',
#  '지',
#  '쟈',
#  '스',
#  '하',
#  '아',
#  '~']

# %%
print("형태소 단위로 문장 분리")
print("----------------------")
print(Okt.morphs(sentence))
print(" ")
print("문장에서 명사 추출")
print("----------------------")
print(Okt.nouns(sentence))
print(" ")
print("품사 태킹(PoS)")
print("----------------------")
print(Okt.pos(sentence))
rst_list = Okt.morphs(sentence)
# Out:
# 형태소 단위로 문장 분리
# ----------------------
# ['OMG', '공부', '하기', '넘', '싫네요', '.', '그래도', '스터디', '해야', '됩니다', '오마이갓', '!', '지쟈스', '하', '아', '~']
#
# 문장에서 명사 추출
# ----------------------
# ['공부', '스터디', '오마이갓', '지쟈스']
#
# 품사 태킹(PoS)
# ----------------------
# [('OMG', 'Alpha'), ('공부', 'Noun'), ('하기', 'Verb'), ('넘', 'Verb'), ('싫네요', 'Adjective'), ('.', 'Punctuation'), ('그래도', 'Adverb'), ('스터디', 'Noun'), ('해야', 'Verb'), ('됩니다', 'Verb'), ('오마이갓', 'Noun'), ('!', 'Punctuation'), ('지쟈스', 'Noun'), ('하', 'Exclamation'), ('아', 'Exclamation'), ('~', 'Punctuation')]

# %% [markdown]
# # 불용어 제거

# %%
stop_words = ". 을 를 하 아 ~ , 게 때 는 !"
stop_words = set(stop_words.split(' '))
word_tokens = Okt.morphs(sentence)

result = [word for word in word_tokens if not word in stop_words]

print('불용어 제거 전 :',list(word_tokens))
print('불용어 제거 후 :',result)
# Out:
# 불용어 제거 전 : ['OMG', '공부', '하기', '넘', '싫네요', '.', '그래도', '스터디', '해야', '됩니다', '오마이갓', '!', '지쟈스', '하', '아', '~']
# 불용어 제거 후 : ['OMG', '공부', '하기', '넘', '싫네요', '그래도', '스터디', '해야', '됩니다', '오마이갓', '지쟈스']

# %% [markdown]
# # 불용어 파일로 불러와서 제거

# %%
f = open("/content/koreanStopwords.txt", 'r')
lines = f.readlines()
stopwords = []
for line in lines:
    line = line.replace('\n', '')
    stopwords.append(line)
f.close()

# %%
print('불용어 단어 리스트: ', ' '.join(stopwords))

# %%
word_tokens = [token for token in word_tokens if token not in stopwords]
preprocessed_text= ' '.join(word_tokens)
print(preprocessed_text)

# %% [markdown]
# # 유의어/동의어 표준화

# %%
import pandas as pd 

synonym_dict = {
                '나' : ['저', '내'],
                '오마이갓' : ['OMG', 'Oh My God'],
                '공부' : ['스터디']
                }
                
apply_mapping = {word:k for k, v in synonym_dict.items() for word in v}
result_list = pd.DataFrame(rst_list).replace(apply_mapping, regex=True).values

print('유의어 처리 전 :',list(word_tokens))
print('유의어 처리 후:', list(result_list.flatten()))
# Out:
# 유의어 처리 전 : ['OMG', '공부', '하기', '넘', '싫네요', '.', '그래도', '스터디', '해야', '됩니다', '오마이갓', '!', '지쟈스', '하', '아', '~']
# 유의어 처리 후: ['오마이갓', '공부', '하기', '넘', '싫네요', '.', '그래도', '공부', '해야', '됩니다', '오마이갓', '!', '지쟈스', '하', '아', '~']

# %% [markdown]
# # 네이버 영화 평점 데이터 로딩

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_df = pd.read_csv('/content/drive/MyDrive/와빅_DA주니어_프로젝트_뮤지컬추천인터페이스/ratings_train.txt', sep='\t')
train_df.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
train_df['label'].value_counts( )
# Out:
# 0    75173
# 1    74827
# Name: label, dtype: int64

# %% [markdown]
# # 데이터 전처리

# %%
import re

train_df = train_df.fillna(' ')
# 정규 표현식을 이용하여 숫자를 공백으로 변경(정규 표현식으로 \d 는 숫자를 의미함.) 
train_df['document'] = train_df['document'].apply( lambda x : re.sub(r"\d+", " ", x) )

# 테스트 데이터 셋을 로딩하고 동일하게 Null 및 숫자를 공백으로 변환
test_df = pd.read_csv('/content/drive/MyDrive/와빅_DA주니어_프로젝트_뮤지컬추천인터페이스/ratings_test.txt', sep='\t')
test_df = test_df.fillna(' ')
test_df['document'] = test_df['document'].apply( lambda x : re.sub(r"\d+", " ", x) )

# id 칼럼 삭제 수행
train_df.drop('id', axis=1, inplace=True) 
test_df.drop('id', axis=1, inplace=True)

# %%
from konlpy.tag import Twitter

twitter = Twitter()
def tw_tokenizer(text):
    # 입력 인자로 들어온 text 를 형태소 단어로 토큰화 하여 list 객체 반환
    tokens_ko = twitter.morphs(text)
    return tokens_ko
# Out:
# /usr/local/lib/python3.10/dist-packages/konlpy/tag/_okt.py:17: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# Twitter 객체의 morphs( ) 객체를 이용한 tokenizer를 사용. ngram_range는 (1,2), TF-IDF 방식을 이용하여 피처벡터화
tfidf_vect = TfidfVectorizer(tokenizer=tw_tokenizer, ngram_range=(1,2), min_df=3, max_df=0.9)
tfidf_vect.fit(train_df['document'])
tfidf_matrix_train = tfidf_vect.transform(train_df['document'])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %% [markdown]
# # 이미 Labeling이 되어있는 데이터에 대한 감성분석(Classification)

# %%
# Logistic Regression 을 이용하여 감성 분석 Classification 수행. 
lg_clf = LogisticRegression(random_state=0, solver='liblinear')

# Parameter C 최적화를 위해 GridSearchCV 를 이용. 
params = { 'C': [1 ,3.5, 4.5, 5.5, 10 ] }
grid_cv = GridSearchCV(lg_clf , param_grid=params , cv=3 ,scoring='accuracy', verbose=1 )
grid_cv.fit(tfidf_matrix_train , train_df['label'] )
print(grid_cv.best_params_ , round(grid_cv.best_score_,4))
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# {'C': 3.5} 0.8593

# %%
from sklearn.metrics import accuracy_score

# 학습 데이터를 적용한 TfidfVectorizer를 이용하여 테스트 데이터를 TF-IDF 값으로 Feature 변환함. 
tfidf_matrix_test = tfidf_vect.transform(test_df['document'])

# classifier 는 GridSearchCV에서 최적 파라미터로 학습된 classifier를 그대로 이용
best_estimator = grid_cv.best_estimator_
preds = best_estimator.predict(tfidf_matrix_test)

print('Logistic Regression 정확도: ',accuracy_score(test_df['label'],preds))
# Out:
# Logistic Regression 정확도:  0.86172

# %% [markdown]
# # 문서 군집화(클러스터를 몇 개로 나누어야 할지는 여러 숫자로 적용해가면서 결과 괜찮은 걸 골라야 할듯?

# %%
from sklearn.cluster import KMeans

# 3개 집합으로 군집화 수행(내가 임의로 선정했음). 예제를 위해 동일한 클러스터링 결과 도출용 random_state=0 
km_cluster = KMeans(n_clusters=3, max_iter=10000, random_state=0)
km_cluster.fit(tfidf_matrix_train)
cluster_label = km_cluster.labels_
cluster_centers = km_cluster.cluster_centers_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
train_df['cluster_label'] = cluster_label
train_df.head()
# Out:
#                                             document  label  cluster_label
# 0                                아 더빙.. 진짜 짜증나네요 목소리      0              0
# 1                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1              2
# 2                                  너무재밓었다그래서보는것을추천한다      0              2
# 3                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0              0
# 4  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1              2

# %%
train_df[train_df['cluster_label']==0].head(20)
# Out:
#                                               document  label  cluster_label
# 0                                  아 더빙.. 진짜 짜증나네요 목소리      0              0
# 3                        교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0              0
# 7    별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단...      0              0
# 9        왜케 평점이 낮은건데? 꽤 볼만한데.. 헐리우드식 화려함에만 너무 길들여져 있나?      1              0
# 25        다 짤랐을꺼야. 그래서 납득할 수 없었던거야.. 그럴꺼야.. 꼭 그랬던걸꺼야..      0              0
# 29               센스있는 연출력..탁월한 캐스팅.. 년대의 향수.. 그래서  점..      1              0
# 31                            졸쓰레기 진부하고말도안됌ㅋㅋ 아..시간아까워      0              0
# 80               뭐냐..시작하고  분만에 나왔다. 리플릿 사진 보며 불안하더니만..      0              0
# 86                                             별루 였다..      0              0
# 89                        ㅋㅋㅋ 진짜 골깜..ㅋㅋ 눈 부라릴때 쓰러짐..ㅋㅋ      1              0
# 104                                 무섭지도 않았고 스토리도 ..ㅡㅡ      0              0
# ...

# %%
train_df[train_df['cluster_label']==1].head(20)
# Out:
#                                               document  label  cluster_label
# 5        막 걸음마 뗀  세부터 초등학교  학년생인  살용영화.ㅋㅋㅋ...별반개도 아까움.      0              1
# 6                                원작의 긴장감을 제대로 살려내지못했다.      0              1
# 10                                    걍인피니트가짱이다.진짜짱이다♥      1              1
# 13   담백하고 깔끔해서 좋다. 신문기사로만 보다 보면 자꾸 잊어버린다. 그들도 사람이었다...      1              1
# 19                  약탈자를 위한 변명, 이라. 저놈들은 착한놈들 절대 아닌걸요.      1              1
# 20           나름 심오한 뜻도 있는 듯. 그냥 학생이 선생과 놀아나는 영화는 절대 아님      1              1
# 23                        절대 평범한 영화가 아닌 수작이라는걸 말씀드립니다.      1              1
# 41   '다 알바생인가 내용도 없고 무서운거도 없고 웃긴거도 하나도 없음 완전 별싱거운 영...      0              1
# 44   윤제문이라는 멋진 배우를 발견하게 됐어요. 소소한 일탈이 잔잔한 미소를 머금게 합니...      1              1
# 46   리얼리티가 뛰어나긴 한데 큰 공감은 안간다. 이민기캐릭터는 정신의학상 분노조절장애 ...      0              1
# 57   너무 충격적이엇다. 기분을 완전히 푹 꺼지게 하는 느낌... 활력이라고는 하나도 없...      1              1
# ...

# %%
train_df[train_df['cluster_label']==2].head(20)
# Out:
#                                              document  label  cluster_label
# 1                   흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1              2
# 2                                   너무재밓었다그래서보는것을추천한다      0              2
# 4   사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1              2
# 8                              액션이 없는데도 재미 있는 몇안되는 영화      1              2
# 11         볼때마다 눈물나서 죽겠다 년대의 향수자극!!허진호는 감성절제멜로의 달인이다~      1              2
# 12                울면서 손들고 횡단보도 건널때 뛰쳐나올뻔 이범수 연기 드럽게못해      0              2
# 14  취향은 존중한다지만 진짜 내생에 극장에서 본 영화중 가장 노잼 노감동임 스토리도 어...      0              2
# 15                                   ㄱ냥 매번 긴장되고 재밋음ㅠㅠ      1              2
# 16  참 사람들 웃긴게 바스코가 이기면 락스코라고 까고바비가 이기면 아이돌이라고 깐다.그...      1              2
# 17                 굿바이 레닌 표절인것은 이해하는데 왜 뒤로 갈수록 재미없어지냐      0              2
# 18      이건 정말 깨알 캐스팅과 질퍽하지않은 산뜻한 내용구성이 잘 버무러진 깨알일드!!♥      1              2
# ...

# %% [markdown]
# # 군집별 핵심단어 추출

# %%
train_df_id = pd.read_csv('/content/drive/MyDrive/와빅_DA주니어_프로젝트_뮤지컬추천인터페이스/ratings_train.txt', sep='\t')['id']
train_df_id.head()
# Out:
# 0     9976970
# 1     3819312
# 2    10265843
# 3     9045019
# 4     6483659
# Name: id, dtype: int64

# %%
train_df['id'] = train_df_id
train_df = train_df[['id', 'document', 'cluster_label']]
train_df.head()
# Out:
#          id                                           document  cluster_label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리              0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나              2
# 2  10265843                                  너무재밓었다그래서보는것을추천한다              2
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정              0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...              2

# %%
train_df.shape
# Out:
# (150000, 3)

# %%
cluster_centers = km_cluster.cluster_centers_
print('cluster_centers shape :',cluster_centers.shape)
print(cluster_centers)
# Out:
# cluster_centers shape : (3, 129276)
# [[2.63901531e-03 8.14105934e-06 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [3.16490780e-03 1.14006157e-05 4.57227783e-06 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [9.22450098e-03 9.39598080e-05 9.14068048e-06 ... 3.40645836e-05
#   2.68576262e-05 8.07123773e-06]]

# %%
def get_cluster_details(cluster_model, cluster_data, feature_names, clusters_num, top_n_features=10):
    cluster_details = {}
    
    # cluster_centers array 의 값이 큰 순으로 정렬된 index 값을 반환
    # 군집 중심점(centroid)별 할당된 word 피처들의 거리값이 큰 순으로 값을 구하기 위함.  
    centroid_feature_ordered_ind = cluster_model.cluster_centers_.argsort()[:,::-1]
    
    #개별 군집별로 iteration하면서 핵심단어, 그 단어의 중심 위치 상대값, 대상 파일명 입력
    for cluster_num in range(clusters_num):
        # 개별 군집별 정보를 담을 데이터 초기화. 
        cluster_details[cluster_num] = {}
        cluster_details[cluster_num]['cluster'] = cluster_num
        
        # cluster_centers_.argsort()[:,::-1] 로 구한 index 를 이용하여 top n 피처 단어를 구함. 
        top_feature_indexes = centroid_feature_ordered_ind[cluster_num, :top_n_features]
        top_features = [ feature_names[ind] for ind in top_feature_indexes ]
        
        # top_feature_indexes를 이용해 해당 피처 단어의 중심 위치 상댓값 구함 
        top_feature_values = cluster_model.cluster_centers_[cluster_num, top_feature_indexes].tolist()
        
        # cluster_details 딕셔너리 객체에 개별 군집별 핵심 단어와 중심위치 상대값, 그리고 해당 파일명 입력
        cluster_details[cluster_num]['top_features'] = top_features
        cluster_details[cluster_num]['top_features_value'] = top_feature_values
        filenames = cluster_data[cluster_data['cluster_label'] == cluster_num]['id']
        filenames = filenames.values.tolist()
        cluster_details[cluster_num]['id'] = filenames
        
    return cluster_details

# %%
def print_cluster_details(cluster_details):
    for cluster_num, cluster_detail in cluster_details.items():
        print('####### Cluster {0}'.format(cluster_num))
        print('Top features:', cluster_detail['top_features'])
        print('Reviews id :',cluster_detail['id'][:7])
        print('==================================================')

# %%
feature_names = list(tfidf_vect.vocabulary_.keys())

cluster_details = get_cluster_details(cluster_model=km_cluster, cluster_data=train_df,\
                                  feature_names=feature_names, clusters_num=3, top_n_features=10 )
print_cluster_details(cluster_details)
# Out:
# ####### Cluster 0
# Top features: [['국', '산', ' ', '코', '미', '디'], ['던', '지', '면', '서'], ['하', '지', '말', '자', ' ', '.'], ['대', '로'], ['혹', '평'], ['되', '었', '는', '지', ' ', '알'], ['무', '기'], ['표', '현', ' ', '하', '지'], ['자', '부', '심'], ['여', '균', '동', ' ', '감', '독']]
# Reviews id : [9976970, 9045019, 9443947, 5912145, 4254115, 8322926, 9005897]
# ...
# ####### Cluster 1
# Top features: [['아', '니', '지', '만'], ['하', '지', '말', '자', ' ', '.'], ['던', '지', '면', '서'], ['자', '부', '심'], ['의', ' ', '정', '말'], ['북', '한', ' ', '에', '서'], ['대', '로'], ['표', '현', ' ', '하', '지'], ['할', ' ', '이', '유'], ['중', '반', ' ', '까', '지']]
# Reviews id : [5403919, 7797314, 9008700, 8628627, 3989148, 4581211, 471131]
# ...
# ####### Cluster 2
# Top features: [['하', '지', '말', '자', ' ', '.'], ['던', '지', '면', '서'], ['무', '기'], ['자', '부', '심'], ['대', '로'], ['표', '현', ' ', '하', '지'], ['혹', '평'], ['더', ' ', '잘'], ['아'], ['의', ' ', '정', '말']]
# Reviews id : [3819312, 10265843, 6483659, 7156791, 10217543, 5957425, 9864035]
# ...
